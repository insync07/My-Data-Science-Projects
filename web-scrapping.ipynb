# %%
with open('smart.html','r',encoding='utf-8')as f:
    html=f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup=BeautifulSoup(html,'lxml')

# %%
soup.prettify()
# Out:
# '<html class="way-item-finder sm-smc-in" lang="en" style="--window-width: 1039;">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width" name="viewport"/>\n  <title>\n   Mobile Phones In Stock | Smartprix\n  </title>\n  <link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>\n  <meta content="#0a3a75" name="theme-color"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <meta content="app-id=1142915507" name="apple-itunes-app"/>\n  <meta content="171761809591603" property="fb:app_id"/>\n  <link href="https://www.smartprix.com/mobiles/exclude_out_of_stock-exclude_upcoming-stock" rel="canonical"/>\n  <meta content="en_IN" property="og:locale"/>\n  <meta content="Smartprix" property="og:site_name"/>\n  <meta content="https://www.smartprix.com/mobiles/exclude_out_of_stock-stock" property="og:url"/>\n  <meta content="@smartprix" name="twitter:site"/>\n  <meta content="@smartprix" name="twitter:creator"/>\n  <meta content="summary" name="twitter:card"/>\n  <link href="/smartprix_search.xml" rel="search" title="Smartprix Search: Find the best price" type="application/opensearchdescription+xml"/>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"Organization","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","logo":"https://www.smartprix.com/smartprix.png","sameAs":["https://www.facebook.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://www.pinterest.com/smartprixcom/","https://x.com/smartprix","https://t.me/Smartprix_Deals","https://news.google.com/publications/CAAqBwgKMKe7jwswjemiAw","https://whatsapp.com/channel/0029Va91m7GAjPXHDPpBfW2o"]}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"WebSite","@id":"https://www.smartprix.com#website","name":"Smartprix","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Mobile Phones","item":"https://www.smartprix.com/mobiles"},{"@type":"ListItem","position":2,"name":"Mobile Phones In Stock","item":"https://www.smartprix.com/mobiles/exclude_out_of_stock-stock"}]}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"Samsung Galaxy S25 Ultra","url":"https://www.smartprix.com/mobiles/samsung-galaxy-s25-ultra-ppd1p8z4fzt4","image":["https://cdn1.smartprix.com/rx-i3jZEfawx-w1200-h1200/3jZEfawx.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"Infinix Note 60 Pro 5G","url":"https://www.smartprix.com/mobiles/infinix-note-60-pro-5g-ppd1xfo8edjp","image":["https://cdn1.smartprix.com/rx-i50lEHBwQ-w1200-h1200/50lEHBwQ.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"Samsung Galaxy S25 FE","url":"https://www.smartprix.com/mobiles/samsung-galaxy-s25-fe-ppd1ifl43cwc","image":["https://cdn1.smartprix.com/rx-igNNWnxPy-w1200-h1200/gNNWnxPy.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"Vivo V70 5G","url":"https://www.smartprix.com/mobiles/vivo-v70-5g-ppd1xo1y0bku","image":["https://cdn1.smartprix.com/rx-iadMR0WTX-w1200-h1200/adMR0WTX.webp"]},{"@type":"ListItem","additionalType":"Product","position":5,"name":"Vivo V70 Elite 5G (12GB RAM + 256GB)","url":"https://www.smartprix.com/mobiles/vivo-v70-elite-5g-12gb-ram-256gb-ppd1f7brnkpa","image":["https://cdn1.smartprix.com/rx-iF1h040jX-w1200-h1200/F1h040jX.webp"]},{"@type":"ListItem","ad ...

# %%
containers=soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
df=pd.DataFrame({
    'model':name,
    'price':price,
    'rating':specs})

# %%
df.head(10)
# Out:
#                                   model      price rating
# 0              Samsung Galaxy S25 Ultra  ₹1,10,490     93
# 1                 Samsung Galaxy S25 FE    ₹55,999     85
# 2                           Vivo V70 5G    ₹45,999     86
# 3  Vivo V70 Elite 5G (12GB RAM + 256GB)    ₹56,999     89
# 4               Motorola Edge 60 Stylus    ₹17,449     86
# 5              Samsung Galaxy S26 Ultra  ₹1,59,999     91
# 6                    Realme P4 Power 5G    ₹24,890     81
# 7                  OnePlus Nord CE 5 5G    ₹24,998     83
# 8                        Vivo T4 Pro 5G    ₹26,235     82
# 9            Xiaomi Redmi Note 14 SE 5G    ₹13,999     80

# %%
df.isnull().sum()
# Out:
# model       0
# price       0
# rating    442
# dtype: int64

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                                      model      price rating  \
# 0                 Samsung Galaxy S25 Ultra  ₹1,10,490    NaN
# 1                    Samsung Galaxy S25 FE    ₹55,999    NaN
# 2                              Vivo V70 5G    ₹45,999    NaN
# 3     Vivo V70 Elite 5G (12GB RAM + 256GB)    ₹56,999    NaN
# 4                  Motorola Edge 60 Stylus    ₹17,449    NaN
# ...                                    ...        ...    ...
# 1015                               HMD 102     ₹1,199    NaN
# 1016                       Ringme Bold S15     ₹5,999    NaN
# 1017                        Foneme F17 Pro     ₹5,500    NaN
# 1018                      itel Zeno 20 Max     ₹7,990     55
# 1019                  Peace Nova 17 Pro 4G     ₹8,999     51
#
#                                                     sim  \
# 0         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 1         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# ...                                                 ...
# 1015                                           Dual Sim
# 1016                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1017                            Dual Sim, 3G, 4G, Wi-Fi
# 1018                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1019                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                               processor  \
# 0     Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 1             Exynos 2400, Deca Core, 3.2 GHz Processor
# 2       Snapdragon 7 Gen4, Octa Core, 2.8 GHz Processor
# 3        Snapdragon 8s Gen3, Octa Core, 3 GHz Processor
# 4      Snapdragon 7s Gen2, Octa Core, 2.4 GHz Processor
# ...                                                 ...
# 1015                             4 MB RAM, 4 MB inbuilt
# 1016                Helio, Dual Core, 1.3 GHz Processor
# 1017                           Helio, 512 MHz Processor
# 1018                  UNISOC T7100, Octa Core Processor
# 1019                     MTK6739, Single Core Processor
#
#                                            ram  \
# 0                    12 GB RAM, 256 GB inbuilt
# 1                     8 GB RAM, 128 GB inbuilt
# 2                     8 GB RAM, 256 GB inbuilt
# 3                    12 GB RAM, 256 GB inbuilt
# 4                     8 GB RAM, 256 GB inbuilt
# ...                                        ...
# 1015  1000 mAh Battery with 2.7W Fast Charging
# 1016                   3 GB RAM, 64 GB inbuilt
# 1017                   2 GB RAM, 16 GB inbuilt
# 1018                   4 GB RAM, 64 GB inbuilt
# 1019                   4 GB RAM, 64 GB inbuilt
#
#                                       battery  \
# 0     5000 mAh Battery with 45W Fast Charging
# 1     4900 mAh Battery with 45W Fast Charging
# 2     6500 mAh Battery with 90W Fast Charging
# 3     6500 mAh Battery with 90W Fast Charging
# 4     5000 mAh Battery with 68W Fast Charging
# ...                                       ...
# 1015        1.77 inches, 160 x 128 px Display
# 1016                         3260 mAh Battery
# 1017      2000 mAh Battery with Fast Charging
# 1018  5000 mAh Battery with 15W Fast Charging
# 1019                         5000 mAh Battery
#
#                                                 display  \
# 0     6.9 inches, 1440 x 3120 px, 120 Hz Display wit...
# 1     6.7 inches, 1080 x 2340 px, 120 Hz Display wit...
# 2     6.59 inches, 1260 x 2750 px, 120 Hz Display wi...
# 3     6.59 inches, 1260 x 2750 px, 120 Hz Display wi...
# 4     6.7 inches, 1220 x 2712 px, 120 Hz Display wit...
# ...                                                 ...
# 1015                                   QVGA Rear Camera
# 1016  6.3 inches, 2424 x 1080 px Display with Small ...
# 1017                     4 inches, 480 x 320 px Display
# 1018  6.6 inches, 720 x 1612 px, 90 Hz Display with ...
# 1019                 6.56 inches, 1640 x 720 px Display
#
#                                                  camera  \
# 0                 200 MP Quad Rear & 12 MP Front Camera
# 1     50 MP + 12 MP + 8 MP Triple Rear & 12 MP Front...
# 2     50 MP + 50 MP + 8 MP Triple Rear & 50 MP Front...
# 3     50 MP + 50 MP + 8 MP Triple Rear & 50 MP Front...
# 4          50 MP + 13 MP Dual Rear & 32 MP Front Camera
# ...                                                 ...
# 1015                  Memory Card Supported, upto 32 GB
# 1016                                  13 MP Rear Camera
# 1017                      5 MP Rear & 2 MP Front Camera
# 1018                13 MP Dual Rear & 5 MP Front Camera
# 1019                     20 MP Rear & 8 MP Front Camera
#
#                                    card           os
# 0             Memory Card Not Supported  Android v15
# 1             Memory Card Not Supported  Android v16
# 2             Memory Card Not Supported  Android v16
# 3             Memory Card Not Supported  Android v16
# 4      Memory Card Supported, upto 1 TB  Android v15
# ...                                 ...          ...
# 1015                              S30+​          NaN
# 1016                            Android  No FM Radio
# 1017                Android v8.1 (Oreo)  No FM Radio
# 1018              Memory Card Supported  Android v14
# 1019  Memory Card (Hybrid), upto 128 GB  No FM Radio
#
# [1020 rows x 11 columns]
